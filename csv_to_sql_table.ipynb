# %% [markdown]
# ### Packages need for this project

# %%
import pandas as pd
import sqlalchemy

# %% [markdown]
#  ### First we need to make SQL server connection using SQLalchemy module

# %%
engine = sqlalchemy.create_engine('mysql+pymysql://root:Manus1ngh@localhost:3306/Third_party_sales')

# %% [markdown]
# ### WE need to Create empty table

# %%
sql_query = sqlalchemy.text('CREATE TABLE ticket_sales(ticket_id int,trans_date int,event_id int, event_name varchar(50),event_date date,event_type varchar(10),event_city varchar(10),customer_id int,price decimal,num_tickets int )')
result = engine.execute(sql_query)

# %%
# lets read the empty table 
pd.read_sql('select * from ticket_sales',engine)
# Out:
# Empty DataFrame
# Columns: [ticket_id, trans_date, event_id, event_name, event_date, event_type, event_city, customer_id, price, num_tickets]
# Index: []

# %% [markdown]
# ### lets load csv into pandas data frame

# %%
df = pd.read_csv('/Users/singhmandeep06gmail.com/Downloads/third_party_sales_1.csv')

# %%
# data need to be adjusted as we can see columsn df has no columns 
df
# Out:
#    1  2020-08-01  100  The North American International Auto Show  2020-09-01  \
# 0  2  2020-08-03  101                     Carlisle Ford Nationals  2020-09-30
# 1  3  2020-08-03  102           Washington Spirits vs Sky Blue FC  2020-08-30
# 2  4  2020-08-05  103                       Christmas Spectacular  2020-10-05
# 3  5  2020-08-05  100  The North American International Auto Show  2020-09-01
# 4  6  2020-08-05  103                       Christmas Spectacular  2020-10-05
#
#    Exhibition       Michigan   123  35.00  3
# 0  Exhibition       Carlisle   151  43.00  1
# 1      Sports  Washington DC   223  59.34  5
# 2     Theater       New York   223  89.95  2
# 3  Exhibition       Michigan   126  35.00  1
# 4     Theater       New York  1024  89.95  3

# %%
#we need convert columns to list 
a_list = df.columns

# %%
# now add the list as columns 
df.loc[len(df)] = list(a_list)

# %%
df
# Out:
#    1  2020-08-01  100  The North American International Auto Show  2020-09-01  \
# 0  2  2020-08-03  101                     Carlisle Ford Nationals  2020-09-30
# 1  3  2020-08-03  102           Washington Spirits vs Sky Blue FC  2020-08-30
# 2  4  2020-08-05  103                       Christmas Spectacular  2020-10-05
# 3  5  2020-08-05  100  The North American International Auto Show  2020-09-01
# 4  6  2020-08-05  103                       Christmas Spectacular  2020-10-05
# 5  1  2020-08-01  100  The North American International Auto Show  2020-09-01
#
#    Exhibition       Michigan   123  35.00  3
# 0  Exhibition       Carlisle   151   43.0  1
# 1      Sports  Washington DC   223  59.34  5
# 2     Theater       New York   223  89.95  2
# 3  Exhibition       Michigan   126   35.0  1
# 4     Theater       New York  1024  89.95  3
# 5  Exhibition       Michigan   123  35.00  3

# %% [markdown]
# ## Insert colum names now

# %%
df.columns = ['ticket_id','trans_date','event_id','event_name','event_date','event_type','event_city','customer_id','price','num_tickets' ]

# %%
df
# Out:
#   ticket_id  trans_date event_id                                  event_name  \
# 0         2  2020-08-03      101                     Carlisle Ford Nationals
# 1         3  2020-08-03      102           Washington Spirits vs Sky Blue FC
# 2         4  2020-08-05      103                       Christmas Spectacular
# 3         5  2020-08-05      100  The North American International Auto Show
# 4         6  2020-08-05      103                       Christmas Spectacular
# 5         1  2020-08-01      100  The North American International Auto Show
#
#    event_date  event_type     event_city customer_id  price num_tickets
# 0  2020-09-30  Exhibition       Carlisle         151   43.0           1
# 1  2020-08-30      Sports  Washington DC         223  59.34           5
# 2  2020-10-05     Theater       New York         223  89.95           2
# 3  2020-09-01  Exhibition       Michigan         126   35.0           1
# ...

# %% [markdown]
# ## Its time to add data to Sql table

# %%
df.to_sql('ticket_sales',engine,if_exists='replace',index = False)

# %% [markdown]
# ## lets check the table if the data really uploaded

# %%
pd.read_sql('select * from ticket_sales',engine)
# Out:
#   ticket_id  trans_date event_id                                  event_name  \
# 0         2  2020-08-03      101                     Carlisle Ford Nationals
# 1         3  2020-08-03      102           Washington Spirits vs Sky Blue FC
# 2         4  2020-08-05      103                       Christmas Spectacular
# 3         5  2020-08-05      100  The North American International Auto Show
# 4         6  2020-08-05      103                       Christmas Spectacular
# 5         1  2020-08-01      100  The North American International Auto Show
#
#    event_date  event_type     event_city customer_id  price num_tickets
# 0  2020-09-30  Exhibition       Carlisle         151     43           1
# 1  2020-08-30      Sports  Washington DC         223  59.34           5
# 2  2020-10-05     Theater       New York         223  89.95           2
# 3  2020-09-01  Exhibition       Michigan         126     35           1
# ...
